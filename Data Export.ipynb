# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import socket
import time
acc_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
acc_socket.bind(("",8086))
time0 = time.time()
def convword(data):
    high = (data[0])
    low = (data[1])
    val = (high << 8) + low
    if (val >= 0x8000):
        val = -((65535 - val) + 1)
    val /= 16384.0
    return val

t= []
acc1, acc2, acc3 = [],[],[]

file = open('accel.csv','w')

# fig,ax  = plt.subplots(1,figsize=(8,5))
for i in range(100):
    data = acc_socket.recv(40960)
    acc = list(map(convword,[data[0:2],data[2:4],data[4:6]]))
    t = time.time()-time0
    file.write('\t'.join([str(t), str(acc[0]), str(acc[1]), str(acc[2])])+'\n')
#     acc1.append(acc[0])
#     acc2.append(acc[1])
#     acc3.append(acc[2])
#     ax.plot(t,acc1,color="blue") # X
#     ax.plot(t,acc2,color="red") # Y
#     ax.plot(t,acc3,color="green") # Z
#     fig.canvas.draw()

file.close()

# %%
# Out:
# array([-0.06933594, -0.06152344, -0.05810547, -0.05761719, -0.06445312,
#        -0.06298828, -0.06103516, -0.05957031, -0.05615234, -0.05664062,
#        -0.06347656, -0.07788086, -0.06274414, -0.05126953, -0.03930664,
#        -0.05737305, -0.07592773, -0.04882812, -0.05395508, -0.05737305,
#        -0.06298828, -0.06567383, -0.06542969, -0.06005859, -0.06665039,
#        -0.0637207 , -0.04760742, -0.06713867, -0.05688477, -0.06494141,
#        -0.06835938, -0.06347656, -0.05981445, -0.05761719, -0.05615234,
#        -0.05688477, -0.05566406, -0.06787109, -0.06445312, -0.04785156,
#        -0.05395508, -0.05297852, -0.06079102, -0.05566406, -0.06860352,
#        -0.06713867, -0.07617188, -0.06005859, -0.06176758, -0.06396484,
#        -0.06445312, -0.04736328, -0.06176758, -0.0625    , -0.05883789,
#        -0.07226562, -0.06542969, -0.05859375, -0.05517578, -0.05981445,
#        -0.06201172, -0.05834961, -0.06518555, -0.05932617, -0.06445312,
# ...

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
